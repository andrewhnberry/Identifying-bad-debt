# %% [markdown]
# ## Part 2 - Predicting Bad Loans vs Good Loans
#
# There is plenty of different machine learning problems we could tackle with this [lending club dataset](https://www.kaggle.com/wendykan/lending-club-loan-data).
#
# I do plan on doing more than just one machine learning problem. However, for the first one my goal is to figure out how to predict **bad debt vs good debt**. This is a **classic classification problem**, and I will use various classification models to tackle this problem.
#
# **Target Variable:** loan_status

# %%
#importing the holy trinity of data science plugins
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import matplotlib.pyplot as plt 

#Importing

import warnings
warnings.filterwarnings("ignore")

#Sklearn Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

#Sklearn Metrics
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

#Sklearn Preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Step 1: Data Cleaning
#
# Cleaning was done by the data_cleaning_script.py. So, we can just jump straight into the project.

# %%
#Loading the data
df = pd.read_csv('/Users/andrewberry/Downloads/lending-club-loan-data/cleaned_lending_data.csv',
                 low_memory=False, index_col = 0)

#Will use a 5% subset of the dataset (for now), in order to reduce computational time
df = df.sample(frac = 0.05, 
                          random_state = 42)

df.head()
# Out:
#          loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 1204665      12000        12000          12000.0   36 months     15.61
# 2233020      14000        14000          14000.0   36 months     13.59
# 1286927      15000        15000          15000.0   36 months      6.92
# 1809503       9500         9500           9500.0   36 months     18.75
# 812250       20000        20000          20000.0   60 months      9.80
#
#          installment grade sub_grade emp_length home_ownership  annual_inc  \
# 1204665       419.58     D        D1     1 year       MORTGAGE     56000.0
# 2233020       475.71     C        C2    5 years           RENT    102000.0
# 1286927       462.61     A        A4  10+ years       MORTGAGE     50843.0
# 1809503       347.04     D        D3    5 years           RENT     35000.0
# 812250        422.98     B        B3  10+ years       MORTGAGE    101000.0
#
#         verification_status  loan_status pymnt_plan             purpose  \
# 1204665     Source Verified            1          n  debt_consolidation
# 2233020     Source Verified            1          n  debt_consolidation
# 1286927     Source Verified            1          n  debt_consolidation
# 1809503        Not Verified            1          n         credit_card
# 812250         Not Verified            1          n    home_improvement
#
#            dti  delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  \
# 1204665  22.03          0.0             1.0      15.0      0.0       6544
# 2233020  14.69          0.0             1.0       6.0      1.0       6534
# 1286927  13.39          0.0             0.0       5.0      0.0       7317
# 1809503  18.56          0.0             3.0      11.0      0.0      12434
# 812250    7.59          0.0             0.0       9.0      0.0      39519
#
#          revol_util  total_acc initial_list_status  \
# 1204665        35.6       24.0                   f
# 2233020        51.0        9.0                   w
# 1286927        41.8       13.0                   w
# 1809503        56.5       15.0                   f
# 812250         76.3       22.0                   w
#
#          collections_12_mths_ex_med  policy_code application_type  \
# 1204665                         0.0            1       Individual
# 2233020                         0.0            1       Individual
# 1286927                         0.0            1       Individual
# 1809503                         0.0            1       Individual
# 812250                          0.0            1       Individual
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  acc_open_past_24mths  \
# 1204665             0.0           0.0     144804.0                   9.0
# 2233020             0.0         500.0      48974.0                   2.0
# 1286927             0.0           0.0     179716.0                   3.0
# 1809503             0.0           0.0      21798.0                  10.0
# 812250              0.0           0.0     240235.0                   3.0
#
#          avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 1204665      10343.0          4768.0     51.3                       0.0
# 2233020       8162.0          6266.0     51.0                       0.0
# 1286927      35943.0         10183.0     41.8                       0.0
# 1809503       1982.0          4358.0     72.2                       0.0
# 812250       30029.0          6457.0     84.6                       0.0
#
#          delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 1204665          0.0                37.0                  82.0
# 2233020          0.0                64.0                  34.0
# 1286927          0.0                95.0                 265.0
# 1809503          0.0                19.0                  60.0
# 812250           0.0               129.0                 350.0
#
#          mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 1204665                    4.0             4.0       4.0
# 2233020                   21.0             5.0       0.0
# 1286927                    9.0             9.0       2.0
# 1809503                    1.0             1.0       0.0
# 812250                     8.0             8.0       3.0
#
#          mths_since_recent_bc  mths_since_recent_inq  num_accts_ever_120_pd  \
# 1204665                   4.0                    4.0                    0.0
# 2233020                  21.0                    5.0                    0.0
# 1286927                   9.0                   10.0                    1.0
# 1809503                   1.0                    4.0                    0.0
# 812250                    8.0                    8.0                    0.0
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 1204665             2.0              7.0          3.0        3.0        7.0
# 2233020             4.0              4.0          4.0        4.0        5.0
# 1286927             2.0              2.0          3.0        5.0        3.0
# 1809503             6.0              9.0          7.0        7.0        1.0
# 812250              3.0              6.0          4.0        5.0        3.0
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 1204665           10.0           13.0                  7.0      15.0
# 2233020            4.0            4.0                  4.0       6.0
# 1286927            3.0            8.0                  2.0       5.0
# 1809503           10.0           14.0                  9.0      11.0
# 812250             7.0           16.0                  6.0       9.0
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 1204665               0.0           0.0                 0.0
# 2233020               0.0           0.0                 0.0
# 1286927               0.0           0.0                 0.0
# 1809503               0.0           0.0                 0.0
# 812250                0.0           0.0                 0.0
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 1204665                 4.0           100.0              33.3
# 2233020                 1.0           100.0               0.0
# 1286927                 2.0            91.7              66.7
# 1809503                 6.0           100.0              57.1
# 812250                  3.0           100.0             100.0
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 1204665                   0.0        0.0         180428.0            36951.0
# 2233020                   1.0        0.0          66143.0            48974.0
# 1286927                   0.0        0.0         200799.0            10915.0
# 1809503                   0.0        0.0          34459.0            21798.0
# 812250                    0.0        0.0         260411.0            39519.0
#
#          total_bc_limit  total_il_high_credit_limit hardship_flag  \
# 1204665          9800.0                     35428.0             N
# 2233020         12800.0                     53343.0             N
# 1286927         17500.0                     12299.0             N
# 1809503         15700.0                     12459.0             N
# 812250          42000.0                         0.0             N
#
#         disbursement_method  year
# 1204665                Cash  2015
# 2233020                Cash  2017
# 1286927                Cash  2015
# 1809503                Cash  2013
# 812250                 Cash  2016

# %%
#target variable
df_clean['loan_status'].value_counts()
# Out:
# 1    71885
# 0    10815
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Step 2: Baseline Model - Logistic Regression (No Scaling, No Feature Selection, etc)
#
# I want to fit a quick baseline model to this data using logistic regression with optimization of the c perameter.
#
# I do plan on trying these preprocessing methods and models:
# - Scaling (Standard Scaling, Min Max Scaler)
# - PCA
# - OverSampling Target Variable
# - Decision Trees
# - Random Forest
# - Neurel Networks

# %%
y = df_clean['loan_status']
X = df_clean.drop(['loan_status'], axis = 1)
# One-hot encode categorical variables that are left
X = pd.get_dummies(X)

# %%
X.shape
# Out:
# (82700, 142)

# %%
# Instatiate Train_Test_Split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, 
                                                    stratify = y)

# %%
# %%time
#Baseline model
#Instatiate
log_reg_baseline = LogisticRegression()

#Fit
log_reg_baseline.fit(X_train, y_train)

#Predict
baseline_pred_train = log_reg_baseline.predict(X_train)
baseline_pred_test = log_reg_baseline.predict(X_test)

print(classification_report(y_test, baseline_pred_test))
print(f'The AUC score is {roc_auc_score(y_test, baseline_pred_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.00      0.00      2163
#            1       0.87      1.00      0.93     14377
#
#     accuracy                           0.87     16540
#    macro avg       0.68      0.50      0.47     16540
# weighted avg       0.82      0.87      0.81     16540
#
# The AUC score is 0.5001963826552858
# CPU times: user 6.07 s, sys: 80.1 ms, total: 6.15 s
# Wall time: 1.63 s

# %% [markdown]
# Since I'm doing a binary classificaiton problem, I will rank my models based mostly on the AUC score. Which is a great evaluation metric to use for binary classification problems.
#
# ### Step 3 - Scaling the data & PCA anlaysis, see how that effects our model.

# %%
#Scaling the Data
scaler = preprocessing.StandardScaler()

#Instatiate
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#Dimensionality Reduction using PCA
pca = PCA()
pca.fit(X_train_scaled)

#Cumulative Sum of the explained variance plot
plt.figure(figsize=(14,7))
plt.plot(range(1,143), pca.explained_variance_ratio_.cumsum(), marker = 'o')
plt.xlabel('Principal Components')
plt.ylabel('Percentage of Variance Explained')
plt.xticks(range(0,142,5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Doing a PCA anlaysis, it seems as if 80% of the explained variance of our data can be explained between 65 to 70 Principal Components. With 90% of the variance is explained with 80 Principal Components. I will fit my data through 80 Principal components before doing the model. This will help us speed up the computational time.

# %%
pca = PCA(n_components = 80)
pca.fit(X_train_scaled)

#Transforming our data
X_train_PCA = pca.transform(X_train_scaled)
X_test_PCA = pca.transform(X_test_scaled)

# %%
#Second Model - Post Scaling and post PCA anlaysis
#Instatiate
log_reg_baseline = LogisticRegression()

#Fit
log_reg_baseline.fit(X_train_PCA, y_train)

#Predict
m2_pred_train = log_reg_baseline.predict(X_train_PCA)
m2_pred_test = log_reg_baseline.predict(X_test_PCA)

print(classification_report(y_test, m2_pred_test))
print(f'The AUC score is {roc_auc_score(y_test, m2_pred_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.01      0.03      2163
#            1       0.87      1.00      0.93     14377
#
#     accuracy                           0.87     16540
#    macro avg       0.68      0.51      0.48     16540
# weighted avg       0.82      0.87      0.81     16540
#
# The AUC score is 0.5060530845438103

# %% [markdown]
# That is a bit dissapointing I thought there would be a bigger increase at least.

# %% [markdown]
# ## Step 4 - Let's tune our Logistic Regression to see if we could improve on our model

# %%
# List of the various scoring metrics we will observe
validation_score_list = []
accuracy_score_train = []
accuracy_score_test = []
auc_score_list = []
recall_list = []
precision_list = []
f1score_list = []
#c_range to figure out optimzied c-value
c_range = [.000001,.00001,.0001,0.001,0.01,0.1,1]

# %%
# %%time
#Model Loop
count = 0

for c in c_range:
    
    #Instatiate model
    log_reg = LogisticRegression(C=c, n_jobs = -1)
    count += 1
    print(f'Model {count} instatiated.')
    
    #append validation score
    val_score = np.mean(cross_val_score(log_reg, X_train_PCA, y_train, cv = 5))
    validation_score_list.append(val_score)
    
    #Fitting the Model
    log_reg.fit(X_train_PCA, y_train)
    print(f'Model {count} fitted.')
    
    #Predict 
    pred_train = log_reg.predict(X_train_PCA)
    pred_test = log_reg.predict(X_test_PCA)
    print(f'Model {count} predicted.')
    
    #Append the Evaluation Metrics List
    accuracy_score_train.append(accuracy_score(y_train, pred_train))
    accuracy_score_test.append(accuracy_score(y_test, pred_test))
    auc_score_list.append(roc_auc_score(y_test, pred_test))   
    recall_list.append(recall_score(y_test, pred_test))
    precision_list.append(precision_score(y_test, pred_test))
    f1score_list.append(f1_score(y_test, pred_test))
# Out:
# Model 1 instatiated.
# Model 1 fitted.
# Model 1 predicted.
# Model 2 instatiated.
# Model 2 fitted.
# Model 2 predicted.
# Model 3 instatiated.
# Model 3 fitted.
# Model 3 predicted.
# Model 4 instatiated.
# Model 4 fitted.
# Model 4 predicted.
# Model 5 instatiated.
# Model 5 fitted.
# Model 5 predicted.
# Model 6 instatiated.
# Model 6 fitted.
# Model 6 predicted.
# Model 7 instatiated.
# Model 7 fitted.
# Model 7 predicted.
# CPU times: user 19.1 s, sys: 1.88 s, total: 21 s
# Wall time: 1min 46s

# %%
# %matplotlib inline
plt.figure(figsize = (14,7))

plt.subplot(211)
plt.plot(np.log10(c_range), validation_score_list,label="Validation Score",marker='o')
plt.plot(np.log10(c_range), recall_list,label="Recall Score",marker='o')
plt.plot(np.log10(c_range), precision_list,label="Precision Score",marker='o')
plt.plot(np.log10(c_range), f1score_list,label="F1 Score",marker='o')
plt.plot(np.log10(c_range), auc_score_list,label="AUC Score",marker='o')
plt.legend()
plt.xlabel('Regularization Parameter: C')
plt.ylabel('Scores (%)')

plt.subplot(212)
plt.plot(np.log10(c_range), accuracy_score_train,label="train",marker='o')
plt.plot(np.log10(c_range), accuracy_score_test,label="test",marker='o')
plt.legend()
plt.xlabel('Regularization Parameter: C')
plt.ylabel('Scores (%)')

plt.show();

# %% [markdown]
# Mmmmh, a c regularization of .0001 seems to hav eperformed the best. However, not much improvement compared to our last two baseline models. Maybe Logistic Regression just don't perform too well. At least with the sample of our data.

# %% [markdown]
# ## Step 5 - Decision Tree Models

# %%
# List of the various scoring metrics we will observe
validation_score_list_dt = []
accuracy_score_train_dt = []
accuracy_score_test_dt = []
auc_score_list_dt = []
recall_list_dt = []
precision_list_dt = []
f1score_list_dt = []

#Decision Tree Depth Range
depth_range = np.arange(1,50,5)

# %%
# %%time
#Model Loop
count = 0

for i in depth_range:
    # Lets plot out different parameters with 5-fold cross validation

    # Instantiate
    dt = DecisionTreeClassifier(max_depth = i)
    count += 1
    print(f'Model {count} instatiated.')

    val_score = np.mean(cross_val_score(dt, X_train_PCA, y_train, cv = 5))
    validation_score_list.append(val_score)
    
    # Fit
    dt.fit(X_train_PCA, y_train)
    print(f'Model {count} fitted.')

    # predict
    pred_train = dt.predict(X_train_PCA)
    pred_test = dt.predict(X_test_PCA)
    print(f'Model {count} predicted.')
    
    #Append the Evaluation Metrics List
    accuracy_score_train_dt.append(accuracy_score(y_train, pred_train))
    accuracy_score_test_dt.append(accuracy_score(y_test, pred_test))
    auc_score_list_dt.append(roc_auc_score(y_test, pred_test))
    recall_list_dt.append(recall_score(y_test, pred_test))
    precision_list_dt.append(precision_score(y_test, pred_test))
    f1score_list_dt.append(f1_score(y_test, pred_test))
# Out:
# Model 1 instatiated.
# Model 1 fitted.
# Model 1 predicted.
# Model 2 instatiated.
# Model 2 fitted.
# Model 2 predicted.
# Model 3 instatiated.
# Model 3 fitted.
# Model 3 predicted.
# Model 4 instatiated.
# Model 4 fitted.
# Model 4 predicted.
# Model 5 instatiated.
# Model 5 fitted.
# Model 5 predicted.
# Model 6 instatiated.
# Model 6 fitted.
# Model 6 predicted.
# Model 7 instatiated.
# Model 7 fitted.
# Model 7 predicted.
# Model 8 instatiated.
# Model 8 fitted.
# Model 8 predicted.
# Model 9 instatiated.
# Model 9 fitted.
# Model 9 predicted.
# Model 10 instatiated.
# Model 10 fitted.
# Model 10 predicted.
# CPU times: user 10min 6s, sys: 5.14 s, total: 10min 11s
# Wall time: 10min 19s

# %%
# %matplotlib inline
plt.figure(figsize = (14,7))

plt.subplot(211)
#plt.plot(depth_range, validation_score_list_dt,label="Validation Score",marker='o')
plt.plot(depth_range, recall_list_dt,label="Recall Score",marker='o')
plt.plot(depth_range, precision_list_dt,label="Precision Score",marker='o')
plt.plot(depth_range, f1score_list_dt,label="F1 Score",marker='o')
plt.plot(depth_range, auc_score_list_dt,label="AUC Score",marker='o')
plt.legend()
plt.xlabel('max_depth: i')
plt.ylabel('Scores (%)')

plt.subplot(212)
plt.plot(depth_range, accuracy_score_train_dt,label="train",marker='o')
plt.plot(depth_range, accuracy_score_test_dt,label="test",marker='o')
plt.legend()
plt.xlabel('max_depth: i')
plt.ylabel('Scores (%)')

plt.show();

# %% [markdown]
# Interestingly, all the scores seem to convertge around maxdepth of 32 or something, however, there also seems to be some major overfitting with the rain and test scores. Thus something isn't right. But this is the trade off we must accept, in addition, I am using a small sample of data. Would be better if I could run this on a more powerful machine.

# %% [markdown]
# ## Step 7 - Neural Network with Sklearn's MLPClassifier
#
# Let's do something else and go with a the Neural Network route.
# * I will do a tensorflow version with another notebook, in order to not crowd this.

# %%
#Instatiatie our MLPClassifier
mlp = MLPClassifier(solver='lbfgs', 
                    activation = 'relu',
                   hidden_layer_sizes = (100,50,100), 
                    max_iter = 10000)

# %%
mlp.fit(X_train_PCA, y_train)
mlp_pred = mlp.predict(X_test_PCA)

# %%
#Printing out our evaluation metrics
print(roc_auc_score(y_test, mlp_pred))
print(classification_report(y_test, mlp_pred))
# Out:
# 0.5480743260918717
#               precision    recall  f1-score   support
#
#            0       0.20      0.24      0.22      2163
#            1       0.88      0.86      0.87     14377
#
#     accuracy                           0.78     16540
#    macro avg       0.54      0.55      0.54     16540
# weighted avg       0.79      0.78      0.78     16540

# %% [markdown]
# Well look at that, it provided us with the best AUC score! 0.54, much better than 0.5.

# %% [markdown]
# ## Step 7 - Random Forest
#
# Will try a different and simpler coding approach by using gridsearchcv and pipelines to optimize our hyperperameters. I wanted to show the manual way.
#
# WARNING: RUNNING THE CODE BELOW FOR ME CAUSED MY COMPUTER TO GO THROUGH A MEMORY ERROR. I NEED A MORE POWERFUL MACHINE. shame though, even though I used a sample.

# %%
#Instatiating our random forest

rf = RandomForestClassifier()

#The paremeters we want to tune with our random forest
n_estimators_range = [2, 4, 8, 16, 32, 64, 100, 200]
param_grid_rf = dict(n_estimators=n_estimators_range)
print(param_grid_rf)
# Out:
# {'n_estimators': [2, 4, 8, 16, 32, 64, 100, 200]}

# %%
# %%time
grid_rf = GridSearchCV(rf, param_grid_rf, cv=10, scoring='roc_auc',
                        n_jobs = -1)
grid_rf.fit(X_train_PCA, y_train)
print(grid_rf.best_score_)
print(grid_rf.best_params_)

# %%
# %%time
rf_pred = grid_rf.predict(X_test_PCA)
#Printing out our evaluation metrics
print(roc_auc_score(y_test, rf_pred))
print(classification_report(y_test, rf_pred))
